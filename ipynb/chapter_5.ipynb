# %% [markdown]
# # Chapter 5: Getting Started with pandas
#
# pandas support dataframes and dataframes operations. Dataframes can be heterogeneous, unlike arrays.

# %%
# Import packages
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Introduction to pandas Data Structures
#
# There are 2 main structures, `Series` and `DataFrame`.

# %% [markdown]
# ### Series
# A series is a 1D-array-like object containing a single sequence of values (same type) and associated indices. They can be created from lists, arrays, or dictionaries.

# %%
# Create via dictionary
obj = pd.Series({0: 4, 1: 7, 2: -5, 3: 3})

# Convert back to dictionary
obj.to_dict()
# Out:
# {0: 4, 1: 7, 2: -5, 3: 3}

# %%
# Create via list
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %% [markdown]
# Access the array and indices using associated methods.

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [np.int64(4), np.int64(7), np.int64(-5), np.int64(3)]
# Length: 4, dtype: int64

# %% [markdown]
# The index can be set at the point of array creation. or be set afterwards

# %%
# Modify previous series
obj.index = ["d", "b", "a", "c"]
obj
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
# Create new series
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %% [markdown]
# Subset using either position of variable or by name.

# %%
print(obj.iloc[[1, 2]])
print(obj.loc[["b", "a"]])
# Out:
# b    7
# a   -5
# dtype: int64
# b    7
# a   -5
# dtype: int64

# %% [markdown]
# Boolean operations can be performed based on indices.

# %%
"b" in obj
# Out:
# True

# %% [markdown]
# If both a dictionary and an index is provided at creation of series, the custom index will be created first, then valid dictionary data will be appended to the series.

# %%
obj2 = pd.Series({"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000})

obj3 = pd.Series(
    {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000},
    index=["California", "Ohio", "Oregon", "Texas"],
)

# Note that the order of values doesn't match with dictionary order, but with indices.
obj2
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# Arithmetic operations on series automatically aligns series by their index. Afterwards, the indices are also joined.

# %%
obj4 = obj2 + obj3
obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# Both the series data and its index can have names.

# %%
obj4.name = "Population"
obj4.index.name = "State"
obj4
# Out:
# State
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# Name: Population, dtype: float64

# %% [markdown]
# ### DataFrame

# %% [markdown]
# A dataframe is an ordered, named collection of columns. It can be constructed via a dictionary of equal-length 1D arrays.

# %%
data = {
    "state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
    "year": [2000, 2001, 2002, 2001, 2002, 2003],
    "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2],
}

frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# Similar to series, a list of column names can also be passed to order the data.

# %%
frame_ordered = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])
frame_ordered
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %% [markdown]
# Each column can be selected via subsetting or as an attribute.

# %%
frame_ordered[["year"]]
# Out:
#    year
# 0  2000
# 1  2001
# 2  2002
# 3  2001
# 4  2002
# 5  2003

# %%
frame_ordered.debt
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# Name: debt, dtype: object

# %% [markdown]
# Note that attribute-based subsetting only works if the column name does not conflict with methods and is a valid name.

# %%
# This will call the method, not column 2
frame_ordered.pop
# Out:
# <bound method DataFrame.pop of    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN>

# %% [markdown]
# Retrieve rows via row indices using `loc` or `iloc` as with Series

# %%
frame_ordered.loc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %% [markdown]
# Modify columns by assignment. If a series is assigned, the indices will be matched between the dataframe and series.

# %%
frame_ordered["debt"] = np.random.standard_normal(6)
frame_ordered
# Out:
#    year   state  pop      debt
# 0  2000    Ohio  1.5  0.395998
# 1  2001    Ohio  1.7  0.879809
# 2  2002    Ohio  3.6 -0.209176
# 3  2001  Nevada  2.4 -0.075749
# 4  2002  Nevada  2.9  0.999502
# 5  2003  Nevada  3.2  0.452237

# %%
frame_ordered["debt"] = pd.Series([3, 5, 1], index=[2, 4, 5])
frame_ordered
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   NaN
# 1  2001    Ohio  1.7   NaN
# 2  2002    Ohio  3.6   3.0
# 3  2001  Nevada  2.4   NaN
# 4  2002  Nevada  2.9   5.0
# 5  2003  Nevada  3.2   1.0

# %% [markdown]
# The index and columns of DataFrames can have names.

# %%
frame_ordered.index.name = "no"
frame_ordered.columns.name = "Data"
frame_ordered
# Out:
# Data  year   state  pop  debt
# no
# 0     2000    Ohio  1.5   NaN
# 1     2001    Ohio  1.7   NaN
# 2     2002    Ohio  3.6   3.0
# 3     2001  Nevada  2.4   NaN
# 4     2002  Nevada  2.9   5.0
# 5     2003  Nevada  3.2   1.0

# %% [markdown]
# DataFrames can be turned into arrays.

# %%
frame_ordered.to_numpy()
# Out:
# array([[2000, 'Ohio', 1.5, nan],
#        [2001, 'Ohio', 1.7, nan],
#        [2002, 'Ohio', 3.6, 3.0],
#        [2001, 'Nevada', 2.4, nan],
#        [2002, 'Nevada', 2.9, 5.0],
#        [2003, 'Nevada', 3.2, 1.0]], dtype=object)

# %% [markdown]
# ## Essential Functionality

# %% [markdown]
# ### Reindexing

# %% [markdown]
# Use reindexing to create a new dataframe / series from the current dataframe, with new indices following the usual syntax.

# %%
# Create Series
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])

# Expand indices
obj4 = obj3.reindex(np.arange(6))

# Expand indices, interpolate NAs
obj5 = obj3.reindex(np.arange(6), method="ffill")
print("obj3\n", obj3)
print("obj4\n", obj4)
print("obj5\n", obj5)
# Out:
# obj3
#  0      blue
# 2    purple
# 4    yellow
# dtype: object
# obj4
#  0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object
# obj5
#  0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %% [markdown]
# With dataframes, reindex rows with the `index` arg, reindex columns with the `columns` arg.

# %%
# Example df
frame_ordered
# Out:
# Data  year   state  pop  debt
# no
# 0     2000    Ohio  1.5   NaN
# 1     2001    Ohio  1.7   NaN
# 2     2002    Ohio  3.6   3.0
# 3     2001  Nevada  2.4   NaN
# 4     2002  Nevada  2.9   5.0
# 5     2003  Nevada  3.2   1.0

# %%
# Reindex
frame_ordered.reindex(index=[0, 1, 3, 4], columns=["year", "pop"])
# Out:
# Data  year  pop
# no
# 0     2000  1.5
# 1     2001  1.7
# 3     2001  2.4
# 4     2002  2.9

# %% [markdown]
# ### Dropping Entries from an Axis
#
# Similar logic as reindex - pass index and columns labels to drop from data. Note that this does not mutate the original objects.

# %%
# Drop on series
obj5.drop([0, 2, 4])
# Out:
# 1      blue
# 3    purple
# 5    yellow
# dtype: object

# %%
# Drop on DataFrame
frame_ordered.drop(index=[2, 5], columns=["debt"])
# Out:
# Data  year   state  pop
# no
# 0     2000    Ohio  1.5
# 1     2001    Ohio  1.7
# 3     2001  Nevada  2.4
# 4     2002  Nevada  2.9

# %% [markdown]
# ### Indexing, Selection, and Filtering
#
# Use the `loc` and `iloc` methods to subset Series and DataFrames based on indices.

# %%
frame_ordered.iloc[1:5, 1:4]
# Out:
# Data   state  pop  debt
# no
# 1       Ohio  1.7   NaN
# 2       Ohio  3.6   3.0
# 3     Nevada  2.4   NaN
# 4     Nevada  2.9   5.0

# %%
frame_ordered.loc[[0, 1, 2], ["state", "debt"]]
# Out:
# Data state  debt
# no
# 0     Ohio   NaN
# 1     Ohio   NaN
# 2     Ohio   3.0

# %% [markdown]
# ### Arithmetic and Data Alignment
#
# Pandas automatically align Series and DataFrames by their indexes during math operations. However, during these operations, missing values propagate.

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=["a", "c", "e", "f", "g"])

# %%
s1 + s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# By performing additions using appropriate methods and the `fill` argument, missing values can be filled automatically (prior operation).

# %%
s1.add(s2, fill_value=0)
# Out:
# a    5.2
# c    1.1
# d    3.4
# e    0.0
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# #### Operations between DataFrame and Series
#
# When a math operation is performed on a DataFrame on a Series, it is by default performed row by row. Pass the `axis` arg to methods to perform it by column instead.

# %%
# Set up data
frame = pd.DataFrame(
    np.arange(12.0).reshape((4, 3)),
    columns=["b", "d", "e"],
    index=["Utah", "Ohio", "Texas", "Oregon"],
)

rows = pd.Series([4, 3, 2, 1], index=["Utah", "Ohio", "Texas", "Oregon"])

columns = pd.Series([3, 2, 1], index=["b", "d", "e"])

print(frame)
print(columns)
print(rows)
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
# b    3
# d    2
# e    1
# dtype: int64
# Utah      4
# Ohio      3
# Texas     2
# Oregon    1
# dtype: int64

# %%
# Perform operation per row
frame * columns
# Out:
#            b     d     e
# Utah     0.0   2.0   2.0
# Ohio     9.0   8.0   5.0
# Texas   18.0  14.0   8.0
# Oregon  27.0  20.0  11.0

# %%
# Perform per column
frame.add(rows, axis="index")
# Out:
#            b     d     e
# Utah     4.0   5.0   6.0
# Ohio     6.0   7.0   8.0
# Texas    8.0   9.0  10.0
# Oregon  10.0  11.0  12.0

# %% [markdown]
# ### Function Application and Mapping

# %% [markdown]
# NumPy ufuncs can be performed on each cell in a pandas object.

# %%
# Set up data
df1 = pd.DataFrame(
    np.random.standard_normal(12).reshape((4, 3)),
    columns=["b", "d", "e"],
    index=["Utah", "Ohio", "Texas", "Oregon"],
)

df1
# Out:
#                b         d         e
# Utah   -0.943505  0.386808  0.524422
# Ohio   -1.417140 -1.919194 -0.494973
# Texas   0.782057 -1.588690 -0.008988
# Oregon  0.207850 -0.455446 -1.694396

# %%
# Set up data (Series)
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])

s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
# Perform ufunc on each element
np.abs(df1)
# Out:
#                b         d         e
# Utah    0.943505  0.386808  0.524422
# Ohio    1.417140  1.919194  0.494973
# Texas   0.782057  1.588690  0.008988
# Oregon  0.207850  0.455446  1.694396

# %% [markdown]
# Use `apply` to perform a function on a column-wise or row-wise basis, treating each column / row as a 1D array.

# %%
# Define function
def fun(x):
    return x.max() - x.min()

# %%
# Perform across each row
df1.apply(fun, axis="rows")
# Out:
# b    2.199197
# d    2.306002
# e    2.218819
# dtype: float64

# %%
# Perform across each column
df1.apply(fun, axis="columns")
# Out:
# Utah      1.467927
# Ohio      1.424221
# Texas     2.370746
# Oregon    1.902246
# dtype: float64

# %% [markdown]
# Many methods in dataframes are already applied column-wise / row-wise.

# %%
df1.mean()
# Out:
# b   -0.342685
# d   -0.894130
# e   -0.418484
# dtype: float64

# %% [markdown]
# Element-wise functions performing like unary ufuncs can also be defined. Apply them on dataframes with `map`

# %%
# Define function
def fun2(x):
    return f"{x:.2f}"


# Apply function
df1.map(fun2)
# Out:
#             b      d      e
# Utah    -0.94   0.39   0.52
# Ohio    -1.42  -1.92  -0.49
# Texas    0.78  -1.59  -0.01
# Oregon   0.21  -0.46  -1.69

# %% [markdown]
# ### Sorting and Ranking
#
# #### Sorting

# %% [markdown]
# To sort by row or column index, use the `sort_index` method

# %%
# Sort a series
s1.sort_index()
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
# Sort a df by rows
df1.sort_index(axis="rows")
# Out:
#                b         d         e
# Ohio   -1.417140 -1.919194 -0.494973
# Oregon  0.207850 -0.455446 -1.694396
# Texas   0.782057 -1.588690 -0.008988
# Utah   -0.943505  0.386808  0.524422

# %%
# Sort a df by columns
df1.sort_index(axis="columns")
# Out:
#                b         d         e
# Utah   -0.943505  0.386808  0.524422
# Ohio   -1.417140 -1.919194 -0.494973
# Texas   0.782057 -1.588690 -0.008988
# Oregon  0.207850 -0.455446 -1.694396

# %% [markdown]
# To sort by column values, use the `sort_values` method and pass in relevant columns (dataframes)

# %%
df1.sort_values(["b", "e"])
# Out:
#                b         d         e
# Ohio   -1.417140 -1.919194 -0.494973
# Utah   -0.943505  0.386808  0.524422
# Oregon  0.207850 -0.455446 -1.694396
# Texas   0.782057 -1.588690 -0.008988

# %%
s1.sort_values()
# Out:
# c   -2.5
# e    1.5
# d    3.4
# a    7.3
# dtype: float64

# %% [markdown]
# #### Ranking
# The `rank` method returns the indices of a Series or DataFrame such that the Series can be reordered by ascending order following the ranks.

# %%
# Get rank
s1.rank()
# Out:
# a    4.0
# c    1.0
# d    3.0
# e    2.0
# dtype: float64

# %%
# Reorder by ranks
# Take 1 from ranks to get valid indices
s1.iloc[s1.rank() - 1]
# Out:
# e    1.5
# a    7.3
# d    3.4
# c   -2.5
# dtype: float64

# %% [markdown]
# For dataframes, reordering can occur over rows or columns.

# %%
# Over rows (within columns)
df1.rank(axis="rows")
# Out:
#           b    d    e
# Utah    2.0  4.0  4.0
# Ohio    1.0  1.0  2.0
# Texas   4.0  2.0  3.0
# Oregon  3.0  3.0  1.0

# %%
# Over columns (within rows)
df1.rank(axis="columns")
# Out:
#           b    d    e
# Utah    1.0  2.0  3.0
# Ohio    2.0  1.0  3.0
# Texas   3.0  1.0  2.0
# Oregon  3.0  2.0  1.0

# %% [markdown]
# ### Axis Indexes with Duplicate Labels

# %% [markdown]
# Non-unique indexes makes life more difficult. Subsetting a series of dataframe with non-unique indices can produce unexpected datatypes.

# %%
# Create data
## df1 unique
df1 = pd.DataFrame(
    np.random.standard_normal(12).reshape((4, 3)),
    columns=["b", "d", "e"],
    index=["Utah", "Ohio", "Texas", "Oregon"],
)

## df2 nonunique
df2 = pd.DataFrame(
    np.random.standard_normal(12).reshape((4, 3)),
    columns=["b", "d", "e"],
    index=["Utah", "Utah", "Texas", "Oregon"],
)

## s1 unique
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "c", "e"])

## s2 nonunique
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])

# %% [markdown]
# Subsetting a unique index in a series produces a single value, while a non-unique index produces a series.

# %%
# Unique
s1["c"]
# Out:
# np.float64(-2.5)

# %%
# Non-unique
s2["c"]
# Out:
# np.float64(3.6)

# %% [markdown]
# Subsetting a unique index in a series produces a series, while a non-unique index produces a dataframe.

# %%
# Unique
df1.loc["Utah"]
# Out:
# b    0.678092
# d   -0.271152
# e    1.246140
# Name: Utah, dtype: float64

# %%
# Non-unique
df2.loc["Utah"]
# Out:
#              b         d         e
# Utah -1.253575 -0.517886 -1.198158
# Utah  0.886236 -0.455707  0.312410

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %% [markdown]
# Pandas objects have methods for basic summary statistics. For Series, this creates a single summary value, for DataFrame, this creates a series containing summary statistics.

# %%
# Example data
df = pd.DataFrame(
    [[1.4, np.nan], [7.1, -4.5], [np.nan, np.nan], [0.75, -1.3]],
    index=["a", "b", "c", "d"],
    columns=["one", "two"],
)
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
# Sum across rows
df.sum(axis=0)
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
# Sum across columns
df.sum(axis=1)
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %% [markdown]
# By default these methods ignores NAs (as much as possible), but we can also allow NAs to propagate.

# %%
# Mean across columns, ignore NAs
df.mean(axis=1)
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
# Mean across columns, letting NAs propagate
df.mean(axis=1, skipna=False)
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %% [markdown]
# Some methods return indirect statistics.

# %%
df.idxmax(axis=1)
# Out:
# <positron-console-cell-199>:1: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
# a    one
# b    one
# c    NaN
# d    one
# dtype: object

# %% [markdown]
# Some methods are accumulations, containing a result DataFrame of a calculation from left to right or top to bottom.

# %%
# Cumulative sum, top to bottom (row by row)
df.cumsum(axis=0)
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df.cumsum(axis=1)
# Out:
#     one   two
# a  1.40   NaN
# b  7.10  2.60
# c   NaN   NaN
# d  0.75 -0.55

# %% [markdown]
# Some methods are more complex, such as `describe`

# %%
# Describe on a dataframe of numbers
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
# Describe on a series of strings
obj = pd.Series(["a", "a", "b", "c"] * 4)
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %% [markdown]
# ### Correlation and Covariance

# %% [markdown]
# Some summary statistics are computed on pairs of arguments. For example, correlations can be computed on a pair of series (producing a single value), or a DataFrame (producing a correlation matrix)

# %%
# Import example data
price = pd.read_pickle("../examples/yahoo_price.pkl")
volume = pd.read_pickle("../examples/yahoo_price.pkl")

# Calculate percentage change of price
returns = price.pct_change()

# %% [markdown]
# Correlations can be performed on a pair of Series.

# %%
returns["MSFT"].corr(returns["GOOG"])
# Out:
# np.float64(0.46591879490796645)

# %% [markdown]
# Correlations can be performed on a DataFrame.

# %%
returns.corr()
# Out:
#           AAPL      GOOG       IBM      MSFT
# AAPL  1.000000  0.407919  0.386817  0.389695
# GOOG  0.407919  1.000000  0.405099  0.465919
# IBM   0.386817  0.405099  1.000000  0.499764
# MSFT  0.389695  0.465919  0.499764  1.000000

# %% [markdown]
# Or a pair of DataFrame and Series.

# %%
# Same as the last column of the matrix above
returns.corrwith(returns["MSFT"])
# Out:
# AAPL    0.389695
# GOOG    0.465919
# IBM     0.499764
# MSFT    1.000000
# dtype: float64

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %% [markdown]
# Special summary statistics can be derived from string values in a Series.

# %%
# Example data
obj = pd.Series(["c", "a", "d", "a", "a", "b", "b", "c", "c"])

# %% [markdown]
# Get the list of unique values or count of each value using the relevant methods.

# %%
# unique values (equiv to unique() in R)
obj.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
# Count of each unique values (equiv to table() in R)
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %% [markdown]
# Use the `isin` method to perform set membership check. Useful for subsetting DataFrames and Series.

# %%
# Get boolean vector indicating membership
obj.isin(["b", "c"])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
# Subset using vector
obj[obj.isin(["b", "c"])]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object
