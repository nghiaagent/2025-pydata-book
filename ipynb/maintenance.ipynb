# %% [markdown]
# # Interactive scripts for managing this repo

# %%
import pandas as pd
import sys

# %% [markdown]
# ## Order requirements.txt file

# %%
with open("../requirements.txt") as file:
    requirements = pd.read_table(file, header=None)

requirements = requirements.sort_values(by=[0])

# %%
requirements.to_csv(
    "../requirements.txt", sep=" ", columns=[0], header=False, index=False
)
